# %% [markdown]
# ## Process structured data
# - Read and review data
# - Extract necessary keys from json to column
# - Save final df as file for loading

# %%
# Import packages

import numpy as np
import pandas as pd
import json
import time
import csv
from pandas.io.json import json_normalize
import os

# %%
# Read the data file
ksdf = pd.read_json('input_data_files/Kickstarter_2019-07-18T03_20_05_009Z.json', lines=True)

# %%
ksdf.head()
# Out:
#       table_id     robot_id                                run_id  \
# 0  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 1  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 2  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 3  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 4  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
#
#                                                 data
# 0  {'id': 1456501169, 'photo': {'key': 'assets/01...
# 1  {'id': 1259045207, 'photo': {'key': 'assets/01...
# 2  {'id': 577497800, 'photo': {'key': 'assets/012...
# 3  {'id': 521645557, 'photo': {'key': 'assets/012...
# 4  {'id': 504193797, 'photo': {'key': 'assets/011...

# %%
ksdf.shape
# Out:
# (212378, 4)

# %% [markdown]
# # Limit data to US and completed projects

# %%
def get_country(d):
    return d['country']

ksdf['country'] = ksdf['data'].apply(lambda x: get_country(x))

# %%
def get_state(d):
    return d['state']

ksdf['state'] = ksdf['data'].apply(lambda x: get_state(x))

# %%
ksdf.head()
# Out:
#       table_id     robot_id                                run_id  \
# 0  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 1  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 2  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 3  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 4  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
#
#                                                 data country       state
# 0  {'id': 1456501169, 'photo': {'key': 'assets/01...      US    canceled
# 1  {'id': 1259045207, 'photo': {'key': 'assets/01...      ES      failed
# 2  {'id': 577497800, 'photo': {'key': 'assets/012...      US    canceled
# 3  {'id': 521645557, 'photo': {'key': 'assets/012...      US  successful
# 4  {'id': 504193797, 'photo': {'key': 'assets/011...      US      failed

# %%
ksdf_pared = ksdf.copy()[(ksdf['country'] == 'US') & (ksdf['state'].isin(['failed', 'successful']))]

ksdf_pared.shape
# Out:
# (139246, 6)

# %%
ksdf_pared['state'].unique()
# Out:
# array(['successful', 'failed'], dtype=object)

# %%
type(ksdf_pared['data'])
# Out:
# pandas.core.series.Series

# %%
ksdf_pared.shape
# Out:
# (196491, 6)

# %%
ksdf_pared.sample(10)
# Out:
#            table_id     robot_id                                run_id  \
# 20795   Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 122007  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 199181  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 47666   Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 79701   Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 179383  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 89965   Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 70930   Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 32796   Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 105585  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
#
#                                                      data country       state  \
# 20795   {'id': 1316835288, 'photo': {'key': 'assets/01...      US      failed
# 122007  {'id': 1393554486, 'photo': {'key': 'assets/01...      US      failed
# 199181  {'id': 905679522, 'photo': {'key': 'assets/024...      US  successful
# 47666   {'id': 124290710, 'photo': {'key': 'assets/023...      US      failed
# 79701   {'id': 1977273541, 'photo': {'key': 'assets/01...      US      failed
# 179383  {'id': 1760144456, 'photo': {'key': 'assets/01...      US      failed
# 89965   {'id': 588266637, 'photo': {'key': 'assets/012...      US      failed
# 70930   {'id': 1294644168, 'photo': {'key': 'assets/02...      US  successful
# 32796   {'id': 350729554, 'photo': {'key': 'assets/012...      US  successful
# 105585  {'id': 1408548907, 'photo': {'key': 'assets/01...      US      failed
#
#                                               projecturls
# 20795   https://www.kickstarter.com/projects/145624496...
# 122007  https://www.kickstarter.com/projects/154906855...
# 199181  https://www.kickstarter.com/projects/267974484...
# 47666   https://www.kickstarter.com/projects/jendaresu...
# 79701   https://www.kickstarter.com/projects/gaufamily...
# 179383  https://www.kickstarter.com/projects/104821716...
# 89965   https://www.kickstarter.com/projects/115313888...
# 70930   https://www.kickstarter.com/projects/artwalks/...
# 32796   https://www.kickstarter.com/projects/139295367...
# 105585  https://www.kickstarter.com/projects/200842709...

# %% [markdown]
# # Extracting dictionary keys to columns
# - need to iterate over dictionaries in data column
# - grab 'project' values
# - convert 'project' to column
# - concat to df

# %%
# Test extraction of a single key to column

project_col = []

for i in ksdf_pared.data:
    project_url = i['urls']['web']['project']
    project_col.append(project_url)

# %%
len(project_col)
# Out:
# 139246

# %%
project_col[-1]
# Out:
# 'https://www.kickstarter.com/projects/61747643/maranatha-short-film?ref=discovery_category_newest'

# %%
ksdf_pared['projecturls'] = project_col

# %%
# Define a function that checks if the key exists
def check_key(dictionary, key):
    if key in dictionary.keys():
        return dictionary[key]
    else:
        return ""

# %%
# Test function
# check_key(ksdf_pared.loc[655, 'data'], 'id')
# Out:
# 1388506064

# %%
# Define and iterate over all the 1st level keys to be extracted to columns

d_id = []
d_name = []
d_blurb =[]
d_goal =[]
d_pledged =[]
d_currencysym =[]
d_deadline = []
d_statechangedat =[]
d_createdat = []
d_launchedat = []
d_staffpick = []
d_backerscnt = []
d_location = []
d_category = []
d_spotlight = []

    
for i in ksdf_pared.data:
    
    data_id = check_key(i, 'id')
    d_id.append(data_id)
    
    name = check_key(i, 'name')
    d_name.append(name)
    
    blurb = check_key(i, 'blurb')
    d_blurb.append(blurb)
    
    goal = check_key(i, 'goal')
    d_goal.append(goal)
    
    pledged = check_key(i, 'pledged')
    d_pledged.append(pledged)
    
    dollarsign = check_key(i, 'currency_symbol')
    d_currencysym.append(dollarsign)
    
    deadline = check_key(i, 'deadline')
    d_deadline.append(deadline)
                   
    state_changed_at = check_key(i, 'state_changed_at')
    d_statechangedat.append(state_changed_at)
                   
    created_at = check_key(i, 'created_at')
    d_createdat.append(created_at)
                   
    launched_at = check_key(i, 'launched_at')
    d_launchedat.append(launched_at)
                   
    staff_pick = check_key(i, 'staff_pick')
    d_staffpick.append(staff_pick)
                   
    backers_count = check_key(i, 'backers_count')
    d_backerscnt.append(backers_count)
                   
    location = check_key(i, 'location')
    d_location.append(location)
                   
    category = check_key(i, 'category')
    d_category.append(category)
                   
    spotlight = check_key(i, 'spotlight')
    d_spotlight.append(spotlight)

# %%
# Conduct similar iteration for nested keys
location_id = []
location_name = []
location_state = []
category_id = []
category_name = []
category_slug = []

# For each nested key, check that it's a dictionary and append the value, if not return empty

# For nested location data
for i in d_location:
    if type(i) == dict:
        locationid = check_key(i, 'id')
        location_id.append(locationid)
    else:
        location_id.append("")
        
for i in d_location:
    if type(i) == dict:
        locationname = check_key(i, 'name')
        location_name.append(locationname)
    else:
        location_name.append("")
        
for i in d_location:
    if type(i) == dict:
        locationstate = check_key(i, 'state')
        location_state.append(locationstate)
    else:
        location_state.append("")

# For nested category data
for i in d_category:
    if type(i) == dict:
        categoryid = check_key(i, 'id')
        category_id.append(categoryid)
    else:
        category_id.append("")
        
for i in d_category:
    if type(i) == dict:
        categoryname = check_key(i, 'name')
        category_name.append(categoryname)
    else:
        category_name.append("")

for i in d_category:
    if type(i) == dict:
        categoryslug = check_key(i, 'slug')
        category_slug.append(categoryslug)
    else:
        category_slug.append("")

# %%
# Check to see that all the lists have the same length

lists = [d_id,
d_name,
d_blurb ,
d_goal,
d_pledged,
d_currencysym ,
d_deadline,
d_statechangedat,
d_createdat,
d_launchedat,
d_staffpick,
d_backerscnt,
d_category,
d_spotlight,
location_id,
location_name ,
location_state ,
category_id,
category_name ,
category_slug
        ]
it = iter(lists)
the_len = len(next(it))

if not all(len(l) == the_len for l in it):
    raise ValueError('not all lists have same length!')

# %%
# Make a copy of dataframe to be safe

ksdf_pcopy = ksdf_pared.copy()

# %%
ksdf_pcopy.sample(10)
# Out:
#            table_id     robot_id                                run_id  \
# 184644  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 203639  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 208478  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 35090   Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 64007   Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 147726  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 84731   Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 192428  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 100325  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 124153  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
#
#                                                      data country       state  \
# 184644  {'id': 477263730, 'photo': {'key': 'assets/011...      US  successful
# 203639  {'id': 1909527085, 'photo': {'key': 'assets/01...      US  successful
# 208478  {'id': 1513307111, 'photo': {'key': 'assets/01...      US  successful
# 35090   {'id': 1446656383, 'photo': {'key': 'assets/01...      US  successful
# 64007   {'id': 1765235207, 'photo': {'key': 'assets/01...      US  successful
# 147726  {'id': 2056250552, 'photo': {'key': 'assets/02...      US  successful
# 84731   {'id': 780653021, 'photo': {'key': 'assets/021...      US      failed
# 192428  {'id': 1050129003, 'photo': {'key': 'assets/01...      US      failed
# 100325  {'id': 186726844, 'photo': {'key': 'assets/016...      US      failed
# 124153  {'id': 1031555498, 'photo': {'key': 'assets/01...      US  successful
#
#                                               projecturls
# 184644  https://www.kickstarter.com/projects/158626959...
# 203639  https://www.kickstarter.com/projects/651841039...
# 208478  https://www.kickstarter.com/projects/166447266...
# 35090   https://www.kickstarter.com/projects/165210922...
# 64007   https://www.kickstarter.com/projects/920311578...
# 147726  https://www.kickstarter.com/projects/brandonfi...
# 84731   https://www.kickstarter.com/projects/429078619...
# 192428  https://www.kickstarter.com/projects/214652118...
# 100325  https://www.kickstarter.com/projects/141821046...
# 124153  https://www.kickstarter.com/projects/372333499...

# %%
ksdf_pcopy.shape
# Out:
# (139246, 7)

# %%
# Concat the lists to a copy of the data frame

ksdf_pcopy['data_id'] = d_id
ksdf_pcopy['d_name'] = d_name
ksdf_pcopy['d_blurb'] = d_blurb
ksdf_pcopy['d_goal'] = d_goal
ksdf_pcopy['d_pledged'] = d_pledged
ksdf_pcopy['d_dollar'] = d_currencysym
ksdf_pcopy['d_deadline'] = d_deadline
ksdf_pcopy['d_statechangedat'] = d_statechangedat
ksdf_pcopy['d_createdat'] = d_createdat
ksdf_pcopy['d_launchedat'] = d_launchedat
ksdf_pcopy['d_staffpick'] = d_staffpick
ksdf_pcopy['d_nobackers'] = d_backerscnt
ksdf_pcopy['d_spotlight'] = d_spotlight
ksdf_pcopy['location_id'] = location_id
ksdf_pcopy['loc_name'] = location_name
ksdf_pcopy['loc_state'] = location_state
ksdf_pcopy['category_id'] = category_id
ksdf_pcopy['cat_name'] = category_name
ksdf_pcopy['cat_slug'] = category_slug

# %%
ksdf_pcopy.sample(20)
# Out:
#            table_id     robot_id                                run_id  \
# 97779   Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 24100   Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 92833   Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 156533  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 31254   Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 30219   Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 39569   Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 119794  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 112278  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 172770  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 173538  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 60215   Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 121585  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 62674   Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 191187  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 155719  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 68035   Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 124013  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 177618  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
# 109910  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z
#
#                                                      data country       state  \
# 97779   {'id': 1308436596, 'photo': {'key': 'assets/01...      US      failed
# 24100   {'id': 1931226286, 'photo': {'key': 'assets/01...      US  successful
# 92833   {'id': 1666227891, 'photo': {'key': 'assets/02...      US  successful
# 156533  {'id': 1794155840, 'photo': {'key': 'assets/01...      US  successful
# 31254   {'id': 634737497, 'photo': {'key': 'assets/012...      US  successful
# 30219   {'id': 1873993845, 'photo': {'key': 'assets/02...      US  successful
# 39569   {'id': 596591038, 'photo': {'key': 'assets/023...      US  successful
# 119794  {'id': 834491219, 'photo': {'key': 'assets/011...      US  successful
# 112278  {'id': 69767453, 'photo': {'key': 'assets/011/...      US  successful
# 172770  {'id': 2130212660, 'photo': {'key': 'assets/02...      US  successful
# 173538  {'id': 1555178962, 'photo': {'key': 'assets/01...      US      failed
# 60215   {'id': 836499128, 'photo': {'key': 'assets/013...      US  successful
# 121585  {'id': 359502142, 'photo': {'key': 'assets/012...      US      failed
# 62674   {'id': 1176847428, 'photo': {'key': 'assets/01...      US  successful
# 191187  {'id': 219673167, 'photo': {'key': 'assets/012...      US      failed
# 155719  {'id': 342980347, 'photo': {'key': 'assets/016...      US  successful
# 68035   {'id': 652095855, 'photo': {'key': 'assets/011...      US      failed
# 124013  {'id': 1723101841, 'photo': {'key': 'assets/01...      US  successful
# 177618  {'id': 1367516565, 'photo': {'key': 'assets/01...      US      failed
# 109910  {'id': 1415399589, 'photo': {'key': 'assets/02...      US      failed
#
#                                               projecturls     data_id  \
# 97779   https://www.kickstarter.com/projects/124572182...  1308436596
# 24100   https://www.kickstarter.com/projects/550011749...  1931226286
# 92833   https://www.kickstarter.com/projects/133110502...  1666227891
# 156533  https://www.kickstarter.com/projects/ca7ch/ca7...  1794155840
# 31254   https://www.kickstarter.com/projects/137095375...   634737497
# 30219   https://www.kickstarter.com/projects/terrencee...  1873993845
# 39569   https://www.kickstarter.com/projects/oddwhimsy...   596591038
# 119794  https://www.kickstarter.com/projects/679109791...   834491219
# 112278  https://www.kickstarter.com/projects/attnwhre/...    69767453
# 172770  https://www.kickstarter.com/projects/threadint...  2130212660
# 173538  https://www.kickstarter.com/projects/142720242...  1555178962
# 60215   https://www.kickstarter.com/projects/161806676...   836499128
# 121585  https://www.kickstarter.com/projects/476328950...   359502142
# 62674   https://www.kickstarter.com/projects/198498282...  1176847428
# 191187  https://www.kickstarter.com/projects/ouroboros...   219673167
# 155719  https://www.kickstarter.com/projects/galleryst...   342980347
# 68035   https://www.kickstarter.com/projects/254262226...   652095855
# 124013  https://www.kickstarter.com/projects/344607580...  1723101841
# 177618  https://www.kickstarter.com/projects/opticdrea...  1367516565
# 109910  https://www.kickstarter.com/projects/115235698...  1415399589
#
#                                                    d_name  \
# 97779                                     The COSMIC band
# 24100               Solo album by Thom Ayres (of Arcanta)
# 92833                                    Ellie Marches On
# 156533                                     CA7CH Lightbox
# 31254                                 Help me buy a loom!
# 30219                                       WICKED ENIGMA
# 39569      Intuitive abstract painting to melodious music
# 119794  Carleigh Nesbit's New Album 'Come Out of the K...
# 112278  Attention, Whore is poor, but for less than a ...
# 172770                                  A Better Backpack
# 173538                              Wild Food - Wild Toni
# 60215   P.A.P.P.i.D.: Post Apocalyptic Pulitzer Prize ...
# 121585     Residential Acoustics: Sound blocking Curtains
# 62674                                      Going, Wanting
# 191187                      HUSH - the horror of identity
# 155719  Gallagher's Art Gallery and Framing Shop start up
# 68035   Rhythmic Waves/Percussion Group/Help Us Launch...
# 124013                          Brandon Bernstein Trio CD
# 177618       Optic Dreams Presents: Kinkychula From Space
# 109910                      The JAWN (Round 1 Investment)
#
#                                                   d_blurb  ...  d_launchedat  \
# 97779   The GREAT,UNIQUE COSMIC NeoSOULjazz COSMIC ban...  ...    1336929594
# 24100   A solo album from the man behind the music of ...  ...    1351111554
# 92833   This book is a gentle way to introduce the imp...  ...    1554739922
# 156533  Designed for smart phones, Lightbox lets you s...  ...    1403013782
# 31254   I want to start making hand woven scarves and ...  ...    1446847091
# 30219                      LGBTQ Murder Mystery Webseries  ...    1530029887
# 39569   creating, for you, an original and delightfull...  ...    1546437843
# 119794  Carleigh Nesbit is going back into the studio ...  ...    1425688522
# 112278  Hey guys, we're going on tour. We really need ...  ...    1368484991
# 172770  Get a better all-day backpack designed to look...  ...    1533732830
# 173538  A web series where I take viewers on culinary ...  ...    1473394946
# 60215   In the darkness of nuclear holocaust, time bri...  ...    1486247463
# 121585  Sleep well: Block up to 90% of noise, 100% of ...  ...    1434729981
# 62674   Weaving together live music and dance Going, W...  ...    1407427164
# 191187  based on a very short film comes the even long...  ...    1432360456
# 155719  I am opening an art gallery and framing shop. ...  ...    1495582830
# 68035   Where percussion instructors and youth with au...  ...    1393606342
# 124013  This will be my first CD released under my own...  ...    1355332406
# 177618  A beautiful space vixen from a planet of giant...  ...    1470679477
# 109910  The "JAWN" a new  Winston Salem NC, restaurant...  ...    1534973846
#
#         d_staffpick d_nobackers  d_spotlight  location_id         loc_name  \
# 97779         False           0        False      2451822        Milwaukee
# 24100         False          34         True      2379574          Chicago
# 92833          True          74         True      2486982        St. Louis
# 156533        False        1631         True      2459115         New York
# 31254         False          12         True      2508349         Tualatin
# 30219         False         124         True      2442047      Los Angeles
# 39569          True          78         True      2427032     Indianapolis
# 119794        False         170         True      2378489  Charlottesville
# 112278        False          23         True      2452078      Minneapolis
# 172770         True        3533         True      2473224       Pittsburgh
# 173538        False          26        False      2479651          Redmond
# 60215         False          44         True      2487129         St. Paul
# 121585        False           9        False      2503863            Tampa
# 62674          True          51         True      2471217     Philadelphia
# 191187        False           0        False      2490383          Seattle
# 155719        False          22         True      2406278   Fountain Hills
# 68035         False          10        False      2430480        Kalamazoo
# 124013        False          70         True      2442047      Los Angeles
# 177618        False           6        False     12589342        Manhattan
# 109910        False          12        False      2522292    Winston-Salem
#
#         loc_state  category_id          cat_name                     cat_slug
# 97779          WI           41              Jazz                   music/jazz
# 24100          IL           42               Pop                    music/pop
# 92833          MO           46  Children's Books  publishing/children's books
# 156533         NY          341         Wearables         technology/wearables
# 31254          OR          355           Weaving               crafts/weaving
# 30219          CA           33         Webseries       film & video/webseries
# 39569          IN           54       Mixed Media              art/mixed media
# 119794         VA           37    Country & Folk         music/country & folk
# 112278         MN           43              Rock                   music/rock
# 172770         PA           28    Product Design        design/product design
# 173538         WA           33         Webseries       film & video/webseries
# 60215          MN          281      Experimental         theater/experimental
# 121585         FL          339             Sound             technology/sound
# 62674          PA          254      Performances           dance/performances
# 191187         WA          294      Experimental    film & video/experimental
# 155719         AZ           23          Painting                 art/painting
# 68035          MI           44       World Music            music/world music
# 124013         CA           41              Jazz                   music/jazz
# 177618         NY          294      Experimental    film & video/experimental
# 109910         NC          312       Restaurants             food/restaurants
#
# [20 rows x 26 columns]

# %%
# Save df to csv
ksdf_pcopy.to_csv('ks_structured.csv', sep='\t')

# %%
# remove the 'data' json field from the df to preserve format when saving
# save as new df
ksdf_cnodata = ksdf_pcopy.drop('data', 1)

# %%
ksdf_cnodata.sample(3)
# Out:
#           table_id     robot_id                                run_id country  \
# 5366   Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z      US
# 28828  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z      US
# 4353   Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z      US
#
#             state                                        projecturls  \
# 5366   successful  https://www.kickstarter.com/projects/143783311...
# 28828  successful  https://www.kickstarter.com/projects/sisl/hot-...
# 4353   successful  https://www.kickstarter.com/projects/christope...
#
#           data_id                                             d_name  \
# 5366     58167066  Mobile Radio/Recording Studio in Medellin Colo...
# 28828  1813895592     Hot Pursuit: How Chilies Set the World on Fire
# 4353     12236287                       Christoper Noyes Summer Tour
#
#                                                  d_blurb   d_goal  ...  \
# 5366   Our aim is to work with the existing network o...  10000.0  ...
# 28828  Until 1493, chili peppers had never left the A...  25000.0  ...
# 4353   I will be going on some tours this summer in s...    900.0  ...
#
#        d_launchedat d_staffpick  d_nobackers  d_spotlight  location_id  \
# 5366     1308679781       False           66         True       368150
# 28828    1544537532        True          169         True     12589335
# 4353     1338392501       False           15         True      2372503
#
#        loc_name  loc_state  category_id          cat_name  \
# 5366   Medellin  Antioquia          239  Radio & Podcasts
# 28828  Brooklyn         NY           30       Documentary
# 4353   Bushnell         IL           44       World Music
#
#                           cat_slug
# 5366   publishing/radio & podcasts
# 28828     film & video/documentary
# 4353             music/world music
#
# [3 rows x 25 columns]

# %%
# Save the final df to csv
ksdf_cnodata.to_csv('ks_struct_nodata.csv', sep='\t', index = False)

# %%
# Perform a test read to ensure the df can be read prior to loading to postgres
test = pd.read_csv('ks_struct_nodata.csv', sep='\t')

# %%
test.head(5)
# Out:
#       table_id     robot_id                                run_id country  \
# 0  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z      US
# 1  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z      US
# 2  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z      US
# 3  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z      US
# 4  Kickstarter  Kickstarter  Kickstarter_2019-07-18T03_20_05_009Z      US
#
#         state                                        projecturls     data_id  \
# 0  successful  https://www.kickstarter.com/projects/184955320...   521645557
# 1      failed  https://www.kickstarter.com/projects/760226815...   504193797
# 2      failed  https://www.kickstarter.com/projects/143006059...  1667139345
# 3      failed  https://www.kickstarter.com/projects/533614462...  1389221860
# 4  successful  https://www.kickstarter.com/projects/131995875...  1730678034
#
#                                               d_name  \
# 0  How to Breathe Underwater/In the Black Box -- ...
# 1  Backpackable one-person high resolution UAV ma...
# 2                                         LOVE STORY
# 3                              Detroit Revue Concert
# 4  Let's Commit (to) a MURDER, SHE WROTE Album of...
#
#                                              d_blurb   d_goal  ...  \
# 0  A surrealist's guide to navigating the dark de...   1500.0  ...
# 1  Continue to develop a user friendly one-person...  10000.0  ...
# 2  LOVE STORY IS ABOUT THE REAL LOVE THAT PEOPLE ...   2500.0  ...
# 3  Together we can bring a star back on the map o...  35500.0  ...
# 4  Songwriter Joel B. New is creating his first-e...   6500.0  ...
#
#    d_launchedat d_staffpick  d_nobackers  d_spotlight  location_id  \
# 0    1465488766       False           44         True    2356940.0
# 1    1397105848       False            3        False    2441116.0
# 2    1376512056       False            5        False    2503713.0
# 3    1375666413       False            0        False    2391585.0
# 4    1457360083       False          165         True    2459115.0
#
#       loc_name  loc_state  category_id     cat_name           cat_slug
# 0       Athens         GA           42          Pop          music/pop
# 1        Logan         UT          336       Flight  technology/flight
# 2  Tallahassee         FL           44  World Music  music/world music
# 3      Detroit         MI           44  World Music  music/world music
# 4     New York         NY           42          Pop          music/pop
#
# [5 rows x 25 columns]
