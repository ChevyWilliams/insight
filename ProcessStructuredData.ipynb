# %% [markdown]
# # Read and Process all Input Data Files
# - Create for loop to read in all Kickstarter json files
# - Flatten json "data" field
# - Select columns for inclusion in analysis
# - Dedupe data

# %%
# Import packages

import numpy as np
import pandas as pd
import json
import time
import csv
from pandas.io.json import json_normalize
import os
from flatten_json import flatten

# %% [markdown]
# ## Test Run on single file prior to looping

# %%
# for each file, read it, flatten it, keep select columns

def process_data(filepath):
    
    # Read json file
    df = pd.read_json(filepath, lines = True)
      
    # flatten data field
    dict_flattened = (flatten(record, '.') for record in df['data'])
    df_new = pd.DataFrame(dict_flattened)
    
    # select only needed columns
    df_new = df_new[['id', 'name', 'blurb', 'goal', 'pledged', 'state', 'country', 'currency_symbol', 'deadline', 'state_changed_at', 'created_at', 'launched_at', 'staff_pick', 'backers_count', 'location.id', 'location.name', 'category.id', 'category.name', 'category.slug', 'spotlight', 'urls.web.project']]

    # add run_id from original df
    df_new['run_id'] = df['run_id']
    
    # dedupe df
    df_new = df_new.drop_duplicates()
    
    # drop all non-US, non-completed projects
    df_new = df_new[(df_new['country'] == 'US') & (df_new['state'].isin(['failed', 'successful']))]
    
    # Pickle the dataframe
    fileroot, fileext = os.path.splitext(filepath)
    output_filename = fileroot + '.pkl'
    df_new.to_pickle(output_filename)
#     
#     
#     df_new.to_csv(output_filename, sep='\t')
#     file = open(output_filename, "w")
#     file.write(text)
    
    
#     file.close()

# %%
process_data('input_data_files/Kickstarter_2018-08-16T03_20_13_856Z.json')

# %%
test = pd.read_pickle('input_data_files/Kickstarter_2018-08-16T03_20_13_856Z.pkl')

# %%
test.sample(5)
# Out:
#                 id                                               name  \
# 26469   1658171328                  Tasting Room at Man Skirt Brewing
# 122436   104490583                                       2ski Brewski
# 147097   911150977                     A New Quarterly on Photography
# 40339    186876047                                   Medal of Victory
# 70856   1930401874  The Illuminated Path:A Journey of Self Love & ...
#
#                                                     blurb     goal   pledged  \
# 26469   So close we can taste it: Help fund the tastin...  15000.0  25240.00
# 122436  A device that allows double fisting with the u...  50000.0     50.00
# 147097  This new independent web magazine brings toget...    120.0    325.00
# 40339   A feature comedy about two AWOL soldiers who a...  40000.0  40365.11
# 70856   In her upcoming book, Toni Chiapelli explores ...   5000.0   5155.00
#
#              state country currency_symbol    deadline  state_changed_at  ...  \
# 26469   successful      US               $  1427333651        1427333655  ...
# 122436      failed      US               $  1441415093        1441415094  ...
# 147097  successful      US               $  1519851600        1519851600  ...
# 40339   successful      US               $  1353463200        1353463233  ...
# 70856   successful      US               $  1299306344        1299306347  ...
#
#         staff_pick  backers_count  location.id  location.name  category.id  \
# 26469        False            164    2415906.0   Hackettstown          307
# 122436       False              1    2459098.0    New Windsor          307
# 147097        True             27   12589335.0       Brooklyn           49
# 40339         True            293    2459115.0       New York           31
# 70856        False             51    2453280.0       Monterey           15
#
#          category.name                category.slug spotlight  \
# 26469           Drinks                  food/drinks      True
# 122436          Drinks                  food/drinks     False
# 147097     Periodicals       publishing/periodicals      True
# 40339   Narrative Film  film & video/narrative film      True
# 70856      Photography                  photography      True
#
#                                          urls.web.project  \
# 26469   https://www.kickstarter.com/projects/138169743...
# 122436  https://www.kickstarter.com/projects/584875962...
# 147097  https://www.kickstarter.com/projects/391287848...
# 40339   https://www.kickstarter.com/projects/535232476...
# 70856   https://www.kickstarter.com/projects/35431595/...
#
#                                       run_id
# 26469   Kickstarter_2018-08-16T03_20_13_856Z
# 122436  Kickstarter_2018-08-16T03_20_13_856Z
# 147097  Kickstarter_2018-08-16T03_20_13_856Z
# 40339   Kickstarter_2018-08-16T03_20_13_856Z
# 70856   Kickstarter_2018-08-16T03_20_13_856Z
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Create a for loop to process and pickle all the data

# %%
import glob

# %%
# package files into a list for iteration
filelist = glob.glob('input_data_files/Kickstarter_*.json')
filelist
# Out:
# ['input_data_files/Kickstarter_2018-12-13T03_20_05_701Z.json',
#  'input_data_files/Kickstarter_2019-02-14T03_20_04_734Z.json',
#  'input_data_files/Kickstarter_2019-06-13T03_20_35_801Z.json',
#  'input_data_files/Kickstarter_2018-09-13T03_20_17_777Z.json',
#  'input_data_files/Kickstarter_2019-03-14T03_20_12_200Z.json',
#  'input_data_files/Kickstarter_2018-10-18T03_20_48_880Z.json',
#  'input_data_files/Kickstarter_2019-01-17T03_20_02_630Z.json',
#  'input_data_files/Kickstarter_2018-11-15T03_20_50_568Z.json',
#  'input_data_files/Kickstarter_2019-08-15T03_20_03_022Z.json',
#  'input_data_files/Kickstarter_2019-04-18T03_20_02_220Z.json',
#  'input_data_files/Kickstarter_2019-07-18T03_20_05_009Z.json',
#  'input_data_files/Kickstarter_2019-05-16T03_20_20_822Z.json']

# %%
for i, filepath in enumerate(filelist):
    process_data(filepath)

# %% [markdown]
# ## Concat the files to create large dataframe

# %%
# Package the list of files for iteration
pkllist = glob.glob('input_data_files/Kickstarter_*.pkl')
pkllist
# Out:
# ['input_data_files/Kickstarter_2019-03-14T03_20_12_200Z.pkl',
#  'input_data_files/Kickstarter_2019-07-18T03_20_05_009Z.pkl',
#  'input_data_files/Kickstarter_2019-04-18T03_20_02_220Z.pkl',
#  'input_data_files/Kickstarter_2019-05-16T03_20_20_822Z.pkl',
#  'input_data_files/Kickstarter_2019-02-14T03_20_04_734Z.pkl',
#  'input_data_files/Kickstarter_2018-10-18T03_20_48_880Z.pkl',
#  'input_data_files/Kickstarter_2019-01-17T03_20_02_630Z.pkl',
#  'input_data_files/Kickstarter_2018-09-13T03_20_17_777Z.pkl',
#  'input_data_files/Kickstarter_2019-08-15T03_20_03_022Z.pkl',
#  'input_data_files/Kickstarter_2018-12-13T03_20_05_701Z.pkl',
#  'input_data_files/Kickstarter_2019-06-13T03_20_35_801Z.pkl',
#  'input_data_files/Kickstarter_2018-11-15T03_20_50_568Z.pkl',
#  'input_data_files/Kickstarter_2018-08-16T03_20_13_856Z.pkl']

# %%
# Iterate over list of files, concatenating and dropping temp_df
concat_df = pd.DataFrame()

for i, file in enumerate(pkllist):
    temp_df = pd.read_pickle(file)
    concat_df = pd.concat([concat_df, temp_df])

# %% [markdown]
# ## Inspect data

# %%
concat_df.shape
# Out:
# (1668216, 22)

# %%
concat_df.sample(10)
# Out:
#                 id                                               name  \
# 91459   1700356381                                         Soothsayer
# 63625   1457203604                  A. Fisher Brewing Company Revived
# 166823   816898077           IF THIS GOES ON - Political SF Anthology
# 88543   1509154758                 Let's Turn Plastic into Dinosaurs!
# 174291   900009369                 SUPPORT AND SAVE NORTH END STUDIOS
# 47989    445001519          New Works, New Dancers, New Perspectives!
# 161309   189208618         Honeybee V2 Playing Cards by Penguin Magic
# 104338   518656702                   Tight Loops presents: "Big Land"
# 109430   458891861  GIRLY: If Online Poker Players Were A Bunch Of...
# 163318  1296631204                            Estill Masonry Artworks
#
#                                                     blurb      goal  pledged  \
# 91459   Soothsayer is a family owned and operated rest...   20000.0  20755.0
# 63625   Est. 1884 before closing 1967, A Fisher Brewin...    7500.0  20427.0
# 166823  A speculative anthology of thirty short storie...   10000.0  12369.8
# 88543   This Summer Solstice, Explore Ecology staff an...    1500.0     60.0
# 174291  SAVE North End Studios\nHELP US PURCHASE THE B...  500000.0     55.0
# 47989   We aim to give new and emerging choreographers...    1300.0   1550.0
# 161309  A beautiful update to the original, sold-out H...   12000.0  13285.0
# 104338  An expedition film into the heart of Labradors...   15000.0  28839.0
# 109430  The pilot episode for a webseries about 4 girl...    5000.0   1686.0
# 163318  We need help publishing 150-200 pages Picture ...   10000.0      0.0
#
#              state country currency_symbol    deadline  state_changed_at  ...  \
# 91459   successful      US               $  1447864346        1447864346  ...
# 63625   successful      US               $  1485932340        1485932342  ...
# 166823  successful      US               $  1530276589        1530276589  ...
# 88543       failed      US               $  1371790800        1371790836  ...
# 174291      failed      US               $  1321467161        1321467163  ...
# 47989   successful      US               $  1362074340        1362074340  ...
# 161309  successful      US               $  1489679962        1489679962  ...
# 104338  successful      US               $  1531886720        1531886720  ...
# 109430      failed      US               $  1304057893        1304057897  ...
# 163318      failed      US               $  1428079225        1428079228  ...
#
#         staff_pick  backers_count  location.id    location.name  category.id  \
# 91459         True            121   12589342.0        Manhattan          312
# 63625        False            229    2487610.0   Salt Lake City          307
# 166823        True            372    2420394.0          Herndon          324
# 88543        False              2    2488828.0    Santa Barbara           53
# 174291       False              3    2391585.0          Detroit           53
# 47989        False             23    2379574.0          Chicago            6
# 161309       False            396    2478521.0   Rancho Cordova          273
# 104338        True            355    2460595.0  North Attleboro           30
# 109430       False             16       3534.0         Montreal           33
# 163318       False              0    2442327.0       Louisville           54
#
#         category.name             category.slug spotlight  \
# 91459     Restaurants          food/restaurants      True
# 63625          Drinks               food/drinks      True
# 166823    Anthologies    publishing/anthologies      True
# 88543      Public Art            art/public art     False
# 174291     Public Art            art/public art     False
# 47989           Dance                     dance      True
# 161309  Playing Cards       games/playing cards      True
# 104338    Documentary  film & video/documentary      True
# 109430      Webseries    film & video/webseries     False
# 163318    Mixed Media           art/mixed media     False
#
#                                          urls.web.project  \
# 91459   https://www.kickstarter.com/projects/240021178...
# 63625   https://www.kickstarter.com/projects/984672884...
# 166823  https://www.kickstarter.com/projects/102233767...
# 88543   https://www.kickstarter.com/projects/135036316...
# 174291  https://www.kickstarter.com/projects/113010464...
# 47989   https://www.kickstarter.com/projects/367488216...
# 161309  https://www.kickstarter.com/projects/penguinma...
# 104338  https://www.kickstarter.com/projects/tightloop...
# 109430  https://www.kickstarter.com/projects/235275055...
# 163318  https://www.kickstarter.com/projects/177479097...
#
#                                       run_id
# 91459   Kickstarter_2019-08-15T03_20_03_022Z
# 63625   Kickstarter_2018-09-13T03_20_17_777Z
# 166823  Kickstarter_2019-04-18T03_20_02_220Z
# 88543   Kickstarter_2018-10-18T03_20_48_880Z
# 174291  Kickstarter_2018-11-15T03_20_50_568Z
# 47989   Kickstarter_2019-04-18T03_20_02_220Z
# 161309  Kickstarter_2018-11-15T03_20_50_568Z
# 104338  Kickstarter_2019-01-17T03_20_02_630Z
# 109430  Kickstarter_2018-08-16T03_20_13_856Z
# 163318  Kickstarter_2018-09-13T03_20_17_777Z
#
# [10 rows x 22 columns]

# %%
concat_df = concat_df.drop_duplicates()

# %%
concat_df.shape
# Out:
# (1668216, 22)

# %%
concat_df.isnull().sum()
# Out:
# id                     0
# name                   0
# blurb                  0
# goal                   0
# pledged                0
# state                  0
# country                0
# currency_symbol        0
# deadline               0
# state_changed_at       0
# created_at             0
# launched_at            0
# staff_pick             0
# backers_count          0
# location.id         5979
# location.name       5979
# category.id            0
# category.name          0
# category.slug          0
# spotlight              0
# urls.web.project       0
# run_id                 0
# dtype: int64

# %%
concat_df.to_pickle('concat_df.pkl')

# %%
# Import package to convert time from unix
from datetime import datetime

# %%
# Convert time 
utc_deadline = datetime.utcfromtimestamp(concat_df['deadline'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-216d94802886> in <module>
#       1 # Convert time
# ----> 2 utc_deadline = datetime.utcfromtimestamp(concat_df['deadline'])
#
# /anaconda3/envs/insight/lib/python3.7/site-packages/pandas/core/series.py in wrapper(self)
#     129         if len(self) == 1:
#     130             return converter(self.iloc[0])
# --> 131         raise TypeError("cannot convert the series to " "{0}".format(str(converter)))
#     132
#     133     wrapper.__name__ = "__{name}__".format(name=converter.__name__)
#
# TypeError: cannot convert the series to <class 'int'>
